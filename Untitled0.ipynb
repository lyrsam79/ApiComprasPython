# %% [markdown]
# <a href="https://colab.research.google.com/github/lyrsam79/ApiComprasPython/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
print('ola mundo')
# Out:
# ola mundo

# %%
import requests
resposta=requests.get('http://compras.dados.gov.br/licitacoes/v1/licitacoes.json?data_publicacao=20240423&data_publicacao_min=20240430')

resposta.json()
# Out:
# {'_links': {'self': {'href': 'http://compras.dados.gov.br/licitacoes/v1/licitacoes.json?data_publicacao=20240423&data_publicacao_min=20240430',
#    'title': 'Lista de licitações filtrados por data_publicacao=20240423, data_publicacao_min=20240430.'},
#   'first': {'href': '/licitacoes/v1/licitacoes.json?data_publicacao=20240423&data_publicacao_min=20240430&offset=0',
#    'title': 'Primeira página'}},
#  '_embedded': {'licitacoes': [{'uasg': 540004,
#     'modalidade': 5,
#     'numero_aviso': 900012024,
#     'identificador': '54000405900012024',
#     'numero_item_licitacao': 3,
#     'tipo_pregao': 'Eletrônico',
#     'situacao_aviso': 'Publicado',
# ...
